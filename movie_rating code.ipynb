# %%
import http.client

conn = http.client.HTTPSConnection("imdb236.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "6ff70a6caemsh0134cb7b9904529p16733fjsn2af07e3ba498",
    'x-rapidapi-host': "imdb236.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/api/imdb/cast/nm0000190/titles", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# [{"id":"tt6773088","url":"https:\/\/www.imdb.com\/title\/tt6773088\/","primaryTitle":"Brothers","originalTitle":"Brothers","type":"tvSeries","description":"It follows McConaughey and Harrelson as they try to live together on a Texas ranch. That close space puts their friendship to the test.","primaryImage":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYWVhNzc1ZjktMWY2ZC00OTQ2LTgwNzEtMTk4MDE5Njc3OGFlXkEyXkFqcGc@.jpg","thumbnails":[{"url":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYWVhNzc1ZjktMWY2ZC00OTQ2LTgwNzEtMTk4MDE5Njc3OGFlXkEyXkFqcGc@._V1_QL75_UX100_CR0,0,100,148_.jpg","width":100,"height":148},{"url":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYWVhNzc1ZjktMWY2ZC00OTQ2LTgwNzEtMTk4MDE5Njc3OGFlXkEyXkFqcGc@._V1_QL75_UX280_CR0,0,280,414_.jpg","width":280,"height":414},{"url":"https:\/\/m.media-amazon.com\/images\/M\/MV5BYWVhNzc1ZjktMWY2ZC00OTQ2LTgwNzEtMTk4MDE5Njc3OGFlXkEyXkFqcGc@._V1_QL75_UX380_CR0,0,380,562_.jpg","width":380,"height":562}],"trailer":null,"contentRating":null,"i
# ...

# %%
import pandas as pd
import json

json_data = json.loads(data.decode("utf-8"))  #json.load() — file se JSON padhta hai (jab data .json file mein saved ho)
                                              #json.loads() — string se JSON padhta hai (jab data text/string ke form mein ho) ← tumhare code mein yahi use hua hai
df = pd.json_normalize(json_data)
df.to_csv("movie_rating.csv" , index=False)
print(df.head())
# Out:
#            id                                     url  \
# 0   tt6773088   https://www.imdb.com/title/tt6773088/
# 1  tt41059410  https://www.imdb.com/title/tt41059410/
# 2  tt21103218  https://www.imdb.com/title/tt21103218/
# 3  tt27706593  https://www.imdb.com/title/tt27706593/
# 4  tt31937790  https://www.imdb.com/title/tt31937790/
#
#                                 primaryTitle  \
# 0                                   Brothers
# 1                Bear Grylls Is Running Wild
# 2                               The Lost Bus
# 3                  The Rivals of Amziah King
# 4  Superhuman Body: World of Medical Marvels
#
#                                originalTitle      type  \
# 0                                   Brothers  tvSeries
# 1                Bear Grylls Is Running Wild  tvSeries
# 2                               The Lost Bus     movie
# 3                  The Rivals of Amziah King     movie
# 4  Superhuman Body: World of Medical Marvels     movie
#
# ...
